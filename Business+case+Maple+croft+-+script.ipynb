# %% [markdown]
# ## Guidelines

# %% [markdown]
# The task involves reading data from an API, saving to a relational database, and compiling the results into a spreadsheet. The API we will be using is the EONET API from NASA: https://eonet.sci.gsfc.nasa.gov/ The events we would like to pull from here are wildfires, severe storms, and landslides from the past month.
#
# The deliverable for this project is a Python script (or set of scripts) that does the following:
#
# 1. Sets up a database to hold the event data
# 2. Downloads the event data from the API
# 3. Saves the data to the database
# 4. Compiles the data into a spreadsheet
# 5. Emails the spreadsheet to an email address specified either as a command-line parameter or by configuration

# %% [markdown]
# ## Input

# %%
email_recepient = 'jb.vanderstraeten@gmail.com'

# %% [markdown]
# # 0. Import libraries

# %%
import json
import requests
import sqlite3
import pandas as pd
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

# %% [markdown]
# # 1. Sets up a database to hold the event data

# %% [markdown]
# ## 1.1 Creation SQLite database

# %%
# Creating and connecting to the database file
conn = sqlite3.connect('EONET_db.sqlite')
c = conn.cursor()

# Creating a new SQLite table
c.execute('''
CREATE TABLE eonet_data 
(event_id text, 
 event_title text,
 event_description text,
 event_link text,
 closed text,
 category_id integer,
 category_title text,
 source_id text,
 source_url text,
 date text,
 geometry_type text,
 coordinates text
 )
 ''')

# Committing changes
conn.commit()

# %% [markdown]
# # 2. Downloads the event data from the API

# %% [markdown]
# ## 2.1 Connect to the EONET API & check connection status

# %%
# Define API parameters. Rational of 60 days parameter is to reduce size of the sample. 
parameters = {'status':'closed','days':'60'}

# Connection to API and get data
fires = requests.get('https://eonet.sci.gsfc.nasa.gov/api/v2.1/categories/8',parameters)
storms = requests.get('https://eonet.sci.gsfc.nasa.gov/api/v2.1/categories/10',parameters)
landslides = requests.get('https://eonet.sci.gsfc.nasa.gov/api/v2.1/categories/14',parameters)

# Verifying connection status
print(fires, storms, landslides)
# Out:
# <Response [200]> <Response [200]> <Response [200]>

# %% [markdown]
# ## 2.2 Define date last month

# %%
fulldate_last_month = datetime.now() - relativedelta(months=1) 
last_month = fulldate_last_month.strftime("%Y-%m")
print(last_month)
# Out:
# 2017-10

# %% [markdown]
# ## 2.3 Data extraction and cleaning

# %%
# Json file dictionnary keys
events_keys = ['id','title','description','link','closed']
categories_keys = ['id','title']
sources_keys = ['id','url']
others_keys = ['date','type','coordinates']

# Extract data from API to list of list

all_incidents =[] 

for i in fires,storms,landslides:
    data = i.json()
    data_string = json.dumps(data)
    data_dictionnary = json.loads(data_string)
      
    for z in range(0,len(data_dictionnary['events'])):
        incident_data = []
        
        for i in events_keys:
            events = data_dictionnary['events'][z][i]
            incident_data.append(events) 
        
        for i in categories_keys:
            categories_data = data_dictionnary['events'][z]['categories'][0][i]
            incident_data.append(categories_data) 
        
        for i in sources_keys:
            sources_data = data_dictionnary['events'][z]['sources'][0][i]
            incident_data.append(sources_data)
        
        for i in others_keys:
            others_data = data_dictionnary['events'][z]['geometries'][0][i]
            if i == 'coordinates':
                others_data = str(others_data)
            incident_data.append(others_data)
        
        # Filter data of last 60 days on last month
        if last_month in incident_data[9]:
            all_incidents.append(incident_data)

# %% [markdown]
# # 3. Saves the data to the database & select october events

# %%
# Transfer data to SQLite database
for i in all_incidents:
    c.execute("INSERT INTO eonet_data VALUES(?,?,?,?,?,?,?,?,?,?,?,?)", (i))

# %%
# Read table in pandas and data cleaning
df = pd.read_sql_query("SELECT * from eonet_data", conn)

for i in ['closed','date']:
    df[i] = df[i].replace(to_replace =['T','Z'],value = ' ', regex=True)

# Visualisation of table
df.head(len(all_incidents))
# Out:
#       event_id                                        event_title  \
# 0   EONET_3345  Wildfire - SE of Cedar City, Utah - United States
# 1   EONET_3346   Wildfire - S of Winslow, Arizona - United States
# 2   EONET_3338  Wildfire - E of Vancouver, Washington - United...
# 3   EONET_3339   Wildfire - S of Winslow, Arizona - United States
# 4   EONET_3341  Wildfire - S of Riverside, California - United...
# 5   EONET_3333                         Northern Corsica Wildfires
# 6   EONET_3349                          Piemonte, Italy Wildfires
# 7   EONET_3355                           Buffalo Fire, California
# 8   EONET_3328                         Central Portugal Wildfires
# 9   EONET_3329     Oakmont Fire (Central LNU Complex), California
# 10  EONET_3310  Wildfire - NE of Irvine, California - United S...
# 11  EONET_3324                                37 Fire, California
# 12  EONET_3312                          Canyon 2 Fire, California
# 13  EONET_3318      Pocket Fire (Central LNU Complex), California
# 14  EONET_3321           La Porte Fire (Wind Complex), California
# 15  EONET_3330  Sulphur Fire (Mendocino Lake Complex), California
# 16  EONET_3314   Partrick Fire (Southern LNU Complex), California
# 17  EONET_3323            Cascade Fire (Wind Complex), California
# 18  EONET_3317  Redwood / Potter Fires (Mendocino Lake Complex...
# 19  EONET_3315       Nuns Fire (Southern LNU Complex), California
# 20  EONET_3319       Tubbs Fire (Central LNU Complex), California
# 21  EONET_3320                          Cherokee Fire, California
# 22  EONET_3316      Atlas Fire (Southern LNU Complex), California
# 23  EONET_3313                           33 Springs Fire, ARIZONA
# 24  EONET_3342                            Tropical Storm Philippe
# 25  EONET_3337                               Tropical Storm Selma
# 26  EONET_3336                                      Typhoon Saola
# 27  EONET_3331                         Tropical Storm Twentyseven
# 28  EONET_3327                                  Super Typhoon Lan
# 29  EONET_3322                                     Typhoon Khanun
# 30  EONET_3308                                  Hurricane Ophelia
# 31  EONET_3307                                     Hurricane Nate
# 32  EONET_3306                               Tropical Storm Ramon
#
#    event_description                                         event_link  \
# 0                     http://eonet.sci.gsfc.nasa.gov/api/v2.1/events...
# 1                     http://eonet.sci.gsfc.nasa.gov/api/v2.1/events...
# 2                     http://eonet.sci.gsfc.nasa.gov/api/v2.1/events...
# 3                     http://eonet.sci.gsfc.nasa.gov/api/v2.1/events...
# 4                     http://eonet.sci.gsfc.nasa.gov/api/v2.1/events...
# 5                     http://eonet.sci.gsfc.nasa.gov/api/v2.1/events...
# 6                     http://eonet.sci.gsfc.nasa.gov/api/v2.1/events...
# 7                     http://eonet.sci.gsfc.nasa.gov/api/v2.1/events...
# 8                     http://eonet.sci.gsfc.nasa.gov/api/v2.1/events...
# 9                     http://eonet.sci.gsfc.nasa.gov/api/v2.1/events...
# 10                    http://eonet.sci.gsfc.nasa.gov/api/v2.1/events...
# 11                    http://eonet.sci.gsfc.nasa.gov/api/v2.1/events...
# 12                    http://eonet.sci.gsfc.nasa.gov/api/v2.1/events...
# 13                    http://eonet.sci.gsfc.nasa.gov/api/v2.1/events...
# 14                    http://eonet.sci.gsfc.nasa.gov/api/v2.1/events...
# 15                    http://eonet.sci.gsfc.nasa.gov/api/v2.1/events...
# 16                    http://eonet.sci.gsfc.nasa.gov/api/v2.1/events...
# 17                    http://eonet.sci.gsfc.nasa.gov/api/v2.1/events...
# 18                    http://eonet.sci.gsfc.nasa.gov/api/v2.1/events...
# 19                    http://eonet.sci.gsfc.nasa.gov/api/v2.1/events...
# 20                    http://eonet.sci.gsfc.nasa.gov/api/v2.1/events...
# 21                    http://eonet.sci.gsfc.nasa.gov/api/v2.1/events...
# 22                    http://eonet.sci.gsfc.nasa.gov/api/v2.1/events...
# 23                    http://eonet.sci.gsfc.nasa.gov/api/v2.1/events...
# 24                    http://eonet.sci.gsfc.nasa.gov/api/v2.1/events...
# 25                    http://eonet.sci.gsfc.nasa.gov/api/v2.1/events...
# 26                    http://eonet.sci.gsfc.nasa.gov/api/v2.1/events...
# 27                    http://eonet.sci.gsfc.nasa.gov/api/v2.1/events...
# 28                    http://eonet.sci.gsfc.nasa.gov/api/v2.1/events...
# 29                    http://eonet.sci.gsfc.nasa.gov/api/v2.1/events...
# 30                    http://eonet.sci.gsfc.nasa.gov/api/v2.1/events...
# 31                    http://eonet.sci.gsfc.nasa.gov/api/v2.1/events...
# 32                    http://eonet.sci.gsfc.nasa.gov/api/v2.1/events...
#
#                   closed  category_id category_title  source_id  \
# 0   2017-11-02 00:00:00             8      Wildfires        PDC
# 1   2017-11-02 00:00:00             8      Wildfires        PDC
# 2   2017-11-01 00:00:00             8      Wildfires        PDC
# 3   2017-10-27 00:00:00             8      Wildfires        PDC
# 4   2017-10-28 00:00:00             8      Wildfires        PDC
# 5   2017-10-23 00:00:00             8      Wildfires       CEMS
# 6   2017-11-02 00:00:00             8      Wildfires       CEMS
# 7   2017-11-14 00:00:00             8      Wildfires    CALFIRE
# 8   2017-10-22 00:00:00             8      Wildfires       CEMS
# 9   2017-10-29 00:00:00             8      Wildfires    CALFIRE
# 10  2017-10-11 00:00:00             8      Wildfires        PDC
# 11  2017-10-12 00:00:00             8      Wildfires    CALFIRE
# 12  2017-10-17 00:00:00             8      Wildfires    CALFIRE
# 13  2017-11-06 00:00:00             8      Wildfires    CALFIRE
# 14  2017-10-28 00:00:00             8      Wildfires    CALFIRE
# 15  2017-10-27 00:00:00             8      Wildfires    CALFIRE
# 16  2017-10-29 00:00:00             8      Wildfires    CALFIRE
# 17  2017-10-28 00:00:00             8      Wildfires    CALFIRE
# 18  2017-10-28 00:00:00             8      Wildfires    CALFIRE
# 19  2017-11-06 00:00:00             8      Wildfires    CALFIRE
# 20  2017-11-06 00:00:00             8      Wildfires    CALFIRE
# 21  2017-10-17 00:00:00             8      Wildfires    CALFIRE
# 22  2017-10-29 00:00:00             8      Wildfires    CALFIRE
# 23  2017-11-15 00:00:00             8      Wildfires    InciWeb
# 24  2017-11-03 00:00:00            10  Severe Storms     UNISYS
# 25  2017-11-02 00:00:00            10  Severe Storms     UNISYS
#
#    geometry_type                                        coordinates
# 0          Point                      [-112.682674661, 37.50696005]
# 1          Point                      [-110.786574051, 34.33226819]
# 2          Point                      [-121.43400016, 45.804158149]
# 3          Point                     [-110.795570081, 34.342259484]
# 4          Point                      [-117.314103711, 33.58837109]
# 5          Point               [9.076704467773425, 42.570908623949]
# 6        Polygon  [[[6.851806640625, 44.9213963685294], [6.85180...
# 7          Point                           [-117.402445, 33.402411]
# 8          Point                        [-7.689599245, 40.58966762]
# 9          Point                             [-122.58152, 38.46123]
# 10         Point                     [-117.734320998, 33.822813747]
# 11         Point                             [-122.47301, 38.14242]
# 12         Point                             [-117.70975, 33.87041]
# 13         Point                             [-122.90939, 38.76549]
# 14         Point                             [-121.40613, 39.39455]
# 15         Point                             [-122.64543, 39.01387]
# 16         Point                             [-122.39052, 38.31802]
# 17         Point                              [-121.4021, 39.32198]
# 18         Point                             [-123.16635, 39.24873]
# 19         Point                               [-122.5209, 38.4041]
# 20         Point                             [-122.62879, 38.60895]
# 21         Point                             [-121.52966, 39.62496]
# 22         Point                             [-122.24367, 38.39206]
# 23         Point                [-111.08722222222, 34.477777777778]
# 24         Point                                      [-82.9, 20.8]
# 25         Point                                      [-89.5, 10.7]
# 26         Point                                      [139.6, 14.2]
# 27         Point                                      [151.7, 12.2]
# 28         Point                                       [136.8, 9.3]
# 29         Point                                      [124.2, 17.7]
# 30         Point                                      [-39.9, 31.1]
# 31         Point                                      [-81.9, 12.2]
# 32         Point                                      [-96.0, 14.3]

# %% [markdown]
# # 4. Compiles the data into a spreadsheet

# %%
# Create a Pandas Excel writer using XlsxWriter as the engine
excel_file_name = 'EONET_data_%s.xlsx' %last_month
writer = pd.ExcelWriter(excel_file_name, engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object
df.to_excel(writer, sheet_name='event_data')
workbook  = writer.book

# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %% [markdown]
# # 5. Emails the spreadsheet to an email address specified either as a command-line parameter or by configuration

# %%
import smtplib,ssl
from email.mime.multipart import MIMEMultipart
from email.mime.base import MIMEBase
from email.mime.text import MIMEText
from email.utils import formatdate
from email import encoders


def send_mail(send_from,send_to,subject,text,files,server,port,username='',password='',isTls=True):
    msg = MIMEMultipart()
    msg['From'] = send_from
    msg['To'] = send_to
    msg['Date'] = formatdate(localtime = True)
    msg['Subject'] = subject
    msg.attach(MIMEText(text))

    part = MIMEBase('application', "octet-stream")
    part.set_payload(open(excel_file_name, "rb").read())
    encoders.encode_base64(part)
    part.add_header('Content-Disposition', 'attachment; filename="EONET_data_%s.xlsx"' %last_month )
    msg.attach(part)

    #context = ssl.SSLContext(ssl.PROTOCOL_SSLv3)
    #SSL connection only working on Python 3+
    smtp = smtplib.SMTP(server, port)
    if isTls:
        smtp.starttls()
    smtp.login(username,password)
    smtp.sendmail(send_from, send_to, msg.as_string())
    smtp.quit()
    
send_mail(send_from='test.maplecroft@gmail.com',send_to=email_recepient,subject='EONET Data (Fires, Storms, Landslides)',text='Hi. You will find attached to this mail the EONET data for the period %s. Cheers. Jean-Bruno' %last_month,files=workbook,server='smtp.gmail.com',port='587',username='test.maplecroft@gmail.com',password='Test1212',isTls=True)
