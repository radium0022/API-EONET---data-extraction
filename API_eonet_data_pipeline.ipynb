# %% [markdown]
# ## Guidelines

# %% [markdown]
# The task involves reading data from an API, saving to a relational database, and compiling the results into a spreadsheet. The API we will be using is the EONET API from NASA: https://eonet.sci.gsfc.nasa.gov/ The events we would like to pull from here are wildfires, severe storms, and landslides from the past month.
#
# The deliverable for this project is a Python script (or set of scripts) that does the following:
#
# 1. Sets up a database to hold the event data
# 2. Downloads the event data from the API
# 3. Saves the data to the database
# 4. Compiles the data into a spreadsheet
# 5. Emails the spreadsheet to an email address specified either as a command-line parameter or by configuration

# %% [markdown]
# ## Input

# %%
email_recepient = 'jb.vanderstraeten@gmail.com'

# %% [markdown]
# # 0. Import libraries

# %%
import json
import requests
import sqlite3
import pandas as pd
from datetime import datetime, timedelta
from dateutil.relativedelta import relativedelta

# %% [markdown]
# # 1. Sets up a database to hold the event data

# %% [markdown]
# ## 1.1 Creation SQLite database

# %%
# Creating and connecting to the database file
conn = sqlite3.connect('EONET_db.sqlite')
c = conn.cursor()

# Creating a new SQLite table

c.execute('''DROP TABLE eonet_data''')
c.execute('''
CREATE TABLE eonet_data 
(event_id text, 
 event_title text,
 event_description text,
 event_link text,
 closed text,
 category_id integer,
 category_title text,
 source_id text,
 source_url text,
 date text,
 geometry_type text,
 coordinates text
 )
 ''')

# Committing changes
conn.commit()

# %% [markdown]
# # 2. Downloads the event data from the API

# %% [markdown]
# ## 2.1 Connect to the EONET API & check connection status

# %%
# Define API parameters. Rational of 60 days parameter is to reduce size of the sample. 
parameters = {'status':'closed','days':'60'}

# Connection to API and get data
fires = requests.get('https://eonet.sci.gsfc.nasa.gov/api/v2.1/categories/8',parameters)
storms = requests.get('https://eonet.sci.gsfc.nasa.gov/api/v2.1/categories/10',parameters)
landslides = requests.get('https://eonet.sci.gsfc.nasa.gov/api/v2.1/categories/14',parameters)

# Verifying connection status
print(fires, storms, landslides)
# Out:
# <Response [200]> <Response [200]> <Response [200]>

# %% [markdown]
# ## 2.2 Define date last month

# %%
fulldate_last_month = datetime.now() - relativedelta(months=1) 
last_month = fulldate_last_month.strftime("%Y-%m")
print(last_month)
last_month = '2017-10'
# Out:
# 2017-11

# %% [markdown]
# ## 2.3 Data extraction and cleaning

# %% [markdown]
# # 3. Saves the data to the database & select october events

# %%
# Json file dictionnary keys
events_keys = ['id','title','description','link','closed']
categories_keys = ['id','title']
sources_keys = ['id','url']
others_keys = ['date','type','coordinates']

# Extract data from API to list of list

all_incidents =[] 

for i in fires,storms,landslides:
    data = i.json()
    print(data)
      
    for z in range(0,len(data['events'])):
        incident_data = []
        
        for i in events_keys:
            events = data['events'][z][i]
            incident_data.append(events) 
        
        for i in categories_keys:
            categories_data = data['events'][z]['categories'][0][i]
            incident_data.append(categories_data) 
        
        for i in sources_keys:
            sources_data = data['events'][z]['sources'][0][i]
            incident_data.append(sources_data)
        
        for i in others_keys:
            others_data = data['events'][z]['geometries'][0][i]
            if i == 'coordinates':
                others_data = str(others_data)
            incident_data.append(others_data)
        
        # Filter data of last 60 days on last month
        if last_month in incident_data[9]:
            all_incidents.append(incident_data)
# Out:
# {'title': 'EONET Events: Wildfires', 'description': 'Wildfires includes all nature of fire, including forest and plains fires, as well as urban and industrial fire events. Fires may be naturally caused or manmade.', 'link': 'https://eonet.sci.gsfc.nasa.gov/api/v2.1/categories/8', 'events': [{'id': 'EONET_3345', 'title': 'Wildfire - SE of Cedar City, Utah - United States', 'description': '', 'link': 'http://eonet.sci.gsfc.nasa.gov/api/v2.1/events/EONET_3345', 'closed': '2017-11-02T00:00:00Z', 'categories': [{'id': 8, 'title': 'Wildfires'}], 'sources': [{'id': 'PDC', 'url': 'http://emops.pdc.org/emops/?hazard_id=75259'}], 'geometries': [{'date': '2017-10-31T19:00:00Z', 'type': 'Point', 'coordinates': [-112.682674661, 37.50696005]}]}, {'id': 'EONET_3346', 'title': 'Wildfire - S of Winslow, Arizona - United States', 'description': '', 'link': 'http://eonet.sci.gsfc.nasa.gov/api/v2.1/events/EONET_3346', 'closed': '2017-11-02T00:00:00Z', 'categories': [{'id': 8, 'title': 'Wildfires'}], 'sources': [{'id': 'PDC', 'url': 'http://emops.pdc.org/emops/?hazard_id=75260'}], 'geometries': [{'date': '2017-10-31T19:00:00Z', 'type': 'Point', 'coordinates': [-110.786574051, 34.33226819]}]}, {'id': 'EONET_3338', 'title': 'Wildfire - E of Vancouver, Washington - United States', 'description': '', 'link': 'http://eonet.sci.gsfc.nasa.gov/api/v2.1/events/EONET_3338', 'closed': '2017-11-01T00:00:00Z', 'categories': [{'id': 8, 'title': 'Wildfires'}], 'sources': [{'id': 'PDC', 'url': 'http://emops.pdc.org/emops/?hazard_id=75097'}], 'geometries': [{'date': '2017-10-26T19:00:00Z', 'type': 'Point', 'coordinates': [-121.43400016, 45.804158149]}]}, {'id': 'EONET_3339', 'title': 'Wildfire - S of Winslow, Arizona - United States', 'description': '', 'link': 'http://eonet.sci.gsfc.nasa.gov/api/v2.1/events/EONET_3339', 'closed': '2017-10-27T00:00:00Z', 'categories': [{'id': 8, 'title': 'Wildfires'}], 'sources': [{'id': 'PDC', 'url': 'http://emops.pdc.org/emops/?hazard_id=75098'}], 'geometries': [{'date': '2017-10-26T19:00:00Z', 'type': 'Point', 'coordinates': [-110.795570081, 34.342259484]}]}, {'id': 'EONET_3341', 'title': 'Wildfire - S of Riverside, California - United States', 'description': '', 'link': 'http://eonet.sci.gsfc.nasa.gov/api/v2.1/events/EONET_3341', 'closed': '2017-10-28T00:00:00Z', 'categories': [{'id': 8, 'title': 'Wildfires'}], 'sources': [{'id': 'PDC', 'url': 'http://emops.pdc.org/emops/?hazard_id=75118'}], 'geometries': [{'date': '2017-10-26T00:00:00Z', 'type': 'Point', 'coordinates': [-117.314103711, 33.58837109]}]}, {'id': 'EONET_3333', 'title': 'Northern Corsica Wildfires', 'description': '', 'link': 'http://eonet.sci.gsfc.nasa.gov/api/v2.1/events/EONET_3333', 'closed': '2017-10-23T00:00:00Z', 'categories': [{'id': 8, 'title': 'Wildfires'}], 'sources': [{'id': 'CEMS', 'url': 'http://emergency.copernicus.eu/mapping/list-of-components/EMSR252'}], 'geometries': [{'date': '2017-10-22T00:00:00Z', 'type': 'Point', 'coordinates': [9.076704467773425, 42.570908623949]}]}, {'id': 'EONET_3349', 'title': 'Piemonte, Italy Wildfires', 'description': '', 'link': 'http://eonet.sci.gsfc.nasa.gov/api/v2.1/events/EONET_3349', 'closed': '2017-11-02T00:00:00Z', 'categories': [{'id': 8, 'title': 'Wildfires'}], 'sources': [{'id': 'CEMS', 'url': 'http://emergency.copernicus.eu/mapping/list-of-components/EMSR253'}], 'geometries': [{'date': '2017-10-22T00:00:00Z', 'type': 'Polygon', 'coordinates': [[[6.851806640625, 44.9213963685294], [6.851806640625, 45.295897034277495], [7.515869140625, 45.295897034277495], [7.515869140625, 44.9213963685294], [6.851806640625, 44.9213963685294]]]}]}, {'id': 'EONET_3355', 'title': 'Buffalo Fire, California', 'description': '', 'link': 'http://eonet.sci.gsfc.nasa.gov/api/v2.1/events/EONET_3355', 'closed': '2017-11-14T00:00:00Z', 'categories': [{'id': 8, 'title': 'Wildfires'}], 'sources': [{'id': 'CALFIRE', 'url': 'http://www.fire.ca.gov/current_incidents/incidentdetails/Index/1905'}], 'geometries': [{'date': '2017-10-17T10:19:00Z', ...
# {'title': 'EONET Events: Severe Storms', 'description': 'Related to the atmospheric aspect of storms (hurricanes, cyclones, tornadoes, etc.). Results of storms may be included under floods, landslides, etc.', 'link': 'https://eonet.sci.gsfc.nasa.gov/api/v2.1/categories/10', 'events': [{'id': 'EONET_3364', 'title': 'Tropical Storm Kirogi', 'description': '', 'link': 'http://eonet.sci.gsfc.nasa.gov/api/v2.1/events/EONET_3364', 'closed': '2017-11-24T00:00:00Z', 'categories': [{'id': 10, 'title': 'Severe Storms'}], 'sources': [{'id': 'UNISYS', 'url': 'http://weather.unisys.com/hurricane/w_pacific/2017/KIROGI/track.dat'}], 'geometries': [{'date': '2017-11-18T00:00:00Z', 'type': 'Point', 'coordinates': [115.0, 11.7]}, {'date': '2017-11-18T06:00:00Z', 'type': 'Point', 'coordinates': [113.4, 11.6]}, {'date': '2017-11-18T12:00:00Z', 'type': 'Point', 'coordinates': [112.2, 11.7]}, {'date': '2017-11-18T18:00:00Z', 'type': 'Point', 'coordinates': [111.8, 10.7]}, {'date': '2017-11-19T00:00:00Z', 'type': 'Point', 'coordinates': [110.7, 10.7]}, {'date': '2017-11-19T06:00:00Z', 'type': 'Point', 'coordinates': [109.0, 11.5]}]}, {'id': 'EONET_3363', 'title': 'Flash Floods, Greece', 'description': 'A slow-moving weather system in the Mediterranean brought torrential rain and flash floods to Greece.', 'link': 'http://eonet.sci.gsfc.nasa.gov/api/v2.1/events/EONET_3363', 'closed': '2017-11-24T00:00:00Z', 'categories': [{'id': 9, 'title': 'Floods'}, {'id': 10, 'title': 'Severe Storms'}], 'sources': [{'id': 'CEMS', 'url': 'http://emergency.copernicus.eu/mapping/list-of-components/EMSR257'}, {'id': 'EO', 'url': 'https://earthobservatory.nasa.gov/NaturalHazards/view.php?id=91287'}], 'geometries': [{'date': '2017-11-14T00:00:00Z', 'type': 'Polygon', 'coordinates': [[[23.37799072265625, 37.91749631548299], [23.37799072265625, 38.13644176100284], [23.87451171875, 38.13644176100284], [23.87451171875, 37.91749631548299], [23.37799072265625, 37.91749631548299]]]}]}, {'id': 'EONET_3354', 'title': 'Tropical Storm Haikui', 'description': '', 'link': 'http://eonet.sci.gsfc.nasa.gov/api/v2.1/events/EONET_3354', 'closed': '2017-11-17T00:00:00Z', 'categories': [{'id': 10, 'title': 'Severe Storms'}], 'sources': [{'id': 'UNISYS', 'url': 'http://weather.unisys.com/hurricane/w_pacific/2017/HAIKUI/track.dat'}], 'geometries': [{'date': '2017-11-10T00:00:00Z', 'type': 'Point', 'coordinates': [118.9, 14.9]}, {'date': '2017-11-10T06:00:00Z', 'type': 'Point', 'coordinates': [118.3, 15.9]}, {'date': '2017-11-10T12:00:00Z', 'type': 'Point', 'coordinates': [117.7, 16.9]}, {'date': '2017-11-10T18:00:00Z', 'type': 'Point', 'coordinates': [117.0, 17.0]}, {'date': '2017-11-11T00:00:00Z', 'type': 'Point', 'coordinates': [115.7, 17.7]}, {'date': '2017-11-11T06:00:00Z', 'type': 'Point', 'coordinates': [115.0, 17.7]}, {'date': '2017-11-11T12:00:00Z', 'type': 'Point', 'coordinates': [114.1, 17.8]}, {'date': '2017-11-11T18:00:00Z', 'type': 'Point', 'coordinates': [113.3, 17.7]}, {'date': '2017-11-12T00:00:00Z', 'type': 'Point', 'coordinates': [112.9, 17.7]}]}, {'id': 'EONET_3350', 'title': 'Tropical Storm Rina', 'description': '', 'link': 'http://eonet.sci.gsfc.nasa.gov/api/v2.1/events/EONET_3350', 'closed': '2017-11-14T00:00:00Z', 'categories': [{'id': 10, 'title': 'Severe Storms'}], 'sources': [{'id': 'UNISYS', 'url': 'http://weather.unisys.com/hurricane/atlantic/2017/RINA/track.dat'}], 'geometries': [{'date': '2017-11-06T06:00:00Z', 'type': 'Point', 'coordinates': [-50.2, 28.9]}, {'date': '2017-11-06T12:00:00Z', 'type': 'Point', 'coordinates': [-50.4, 29.5]}, {'date': '2017-11-06T18:00:00Z', 'type': 'Point', 'coordinates': [-50.0, 29.9]}, {'date': '2017-11-07T00:00:00Z', 'type': 'Point', 'coordinates': [-49.9, 30.4]}, {'date': '2017-11-07T06:00:00Z', 'type': 'Point', 'coordinates': [-49.8, 31.4]}, {'date': '2017-11-07T12:00:00Z', 'type': 'Point', 'coordinates': [-49.3, 32.4]}, {'date': '2017-11-07T18:00:00Z', 'type': 'Point', 'coordinates': [-48.9, 33.8]}, {'date': '2017-11-08T00:00:0 ...
# {'title': 'EONET Events: Landslides', 'description': 'Related to landslides and variations thereof: mudslides, avalanche.', 'link': 'https://eonet.sci.gsfc.nasa.gov/api/v2.1/categories/14', 'events': []}

# %%
# Transfer data to SQLite database
for i in all_incidents:
    c.execute("INSERT INTO eonet_data VALUES(?,?,?,?,?,?,?,?,?,?,?,?)", (i))

# %%
# Read table in pandas and data cleaning
df = pd.read_sql_query("SELECT * from eonet_data", conn)

for i in ['closed','date']:
    df[i] = df[i].replace(to_replace =['T','Z'],value = ' ', regex=True)

# Visualisation of table
df.head(len(all_incidents))
# Out:
#       event_id                                        event_title  \
# 0   EONET_3364                              Tropical Storm Kirogi
# 1   EONET_3363                               Flash Floods, Greece
# 2   EONET_3354                              Tropical Storm Haikui
# 3   EONET_3350                                Tropical Storm Rina
# 4   EONET_3347                                     Typhoon Damrey
# 5   EONET_3345  Wildfire - SE of Cedar City, Utah - United States
# 6   EONET_3346   Wildfire - S of Winslow, Arizona - United States
# 7   EONET_3338  Wildfire - E of Vancouver, Washington - United...
# 8   EONET_3339   Wildfire - S of Winslow, Arizona - United States
# 9   EONET_3341  Wildfire - S of Riverside, California - United...
# 10  EONET_3333                         Northern Corsica Wildfires
# 11  EONET_3349                          Piemonte, Italy Wildfires
# 12  EONET_3355                           Buffalo Fire, California
# 13  EONET_3328                         Central Portugal Wildfires
# 14  EONET_3329     Oakmont Fire (Central LNU Complex), California
# 15  EONET_3310  Wildfire - NE of Irvine, California - United S...
# 16  EONET_3324                                37 Fire, California
# 17  EONET_3312                          Canyon 2 Fire, California
# 18  EONET_3318      Pocket Fire (Central LNU Complex), California
# 19  EONET_3321           La Porte Fire (Wind Complex), California
# 20  EONET_3330  Sulphur Fire (Mendocino Lake Complex), California
# 21  EONET_3314   Partrick Fire (Southern LNU Complex), California
# 22  EONET_3323            Cascade Fire (Wind Complex), California
# 23  EONET_3317  Redwood / Potter Fires (Mendocino Lake Complex...
# 24  EONET_3315       Nuns Fire (Southern LNU Complex), California
# 25  EONET_3319       Tubbs Fire (Central LNU Complex), California
# 26  EONET_3320                          Cherokee Fire, California
# 27  EONET_3316      Atlas Fire (Southern LNU Complex), California
# 28  EONET_3342                            Tropical Storm Philippe
# 29  EONET_3337                               Tropical Storm Selma
# 30  EONET_3336                                      Typhoon Saola
#
#                                     event_description  \
# 0
# 1   A slow-moving weather system in the Mediterran...
# 23         Point                             [-123.16635, 39.24873]
# 24         Point                               [-122.5209, 38.4041]
# 25         Point                             [-122.62879, 38.60895]
# 26         Point                             [-121.52966, 39.62496]
# 27         Point                             [-122.24367, 38.39206]
# 28         Point                                      [-82.9, 20.8]
# 29         Point                                      [-89.5, 10.7]
# 30         Point                                      [139.6, 14.2]

# %% [markdown]
# # 4. Compiles the data into a spreadsheet

# %%
# Create a Pandas Excel writer using XlsxWriter as the engine
excel_file_name = 'EONET_data_%s.xlsx' %last_month
writer = pd.ExcelWriter(excel_file_name, engine='xlsxwriter')

# Convert the dataframe to an XlsxWriter Excel object
df.to_excel(writer, sheet_name='event_data')
workbook  = writer.book

# Close the Pandas Excel writer and output the Excel file.
writer.save()

# %% [markdown]
# # 5. Emails the spreadsheet to an email address specified either as a command-line parameter or by configuration

# %%
import smtplib,ssl
from email.mime.multipart import MIMEMultipart
from email.mime.base import MIMEBase
from email.mime.text import MIMEText
from email.utils import formatdate
from email import encoders


def send_mail(send_from,send_to,subject,text,files,server,port,username='',password='',isTls=True):
    msg = MIMEMultipart()
    msg['From'] = send_from
    msg['To'] = send_to
    msg['Date'] = formatdate(localtime = True)
    msg['Subject'] = subject
    msg.attach(MIMEText(text))

    part = MIMEBase('application', "octet-stream")
    part.set_payload(open(excel_file_name, "rb").read())
    encoders.encode_base64(part)
    part.add_header('Content-Disposition', 'attachment; filename="EONET_data_%s.xlsx"' %last_month )
    msg.attach(part)

    #context = ssl.SSLContext(ssl.PROTOCOL_SSLv3)
    #SSL connection only working on Python 3+
    smtp = smtplib.SMTP(server, port)
    if isTls:
        smtp.starttls()
    smtp.login(username,password)
    smtp.sendmail(send_from, send_to, msg.as_string())
    smtp.quit()
    
send_mail(send_from='test.maplecroft@gmail.com',send_to=email_recepient,subject='EONET Data (Fires, Storms, Landslides)',text='Hi. You will find attached to this mail the EONET data for the period %s. Cheers. Jean-Bruno' %last_month,files=workbook,server='smtp.gmail.com',port='587',username='test.maplecroft@gmail.com',password='Test1212',isTls=True)
